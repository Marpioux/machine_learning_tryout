# %% [markdown]
# ---
# University Paris 1 Panthéon-Sorbonne
#
# Introduction to Machine Learning
#
# Dr. Nourhène BEN RABAH
#
# ---
#
#
# <h1 style="color: blue;"> Lab 1. Data Exploration with Pandas  </h1>
#
#
# #### Here is the documentation for the [`DataFrame`](https://pandas.pydata.org/docs/dev/reference/api/pandas.DataFrame.html) data structure in Pandas.
#
#
# #### You must send the completed notebook to Nourhene.Ben-Rabah@univ-paris1.fr. Please include LastName_FirstName_Lab1_IKSEM in your subject line.
#
# ---

# %% [markdown]
# <h2 style="color: blue;"> Part 1: Reading, Quick Exploration, and Selection</h2>
#
# #### Step 0. Import the Pandas library

# %%
from pandas import *

# %% [markdown]
# #### Step 1. Import the dataset
#
# You will start by importing the file *fromage.csv*. To do this, use the [`read_csv`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html) function.

# %%
datas = read_csv("C:/Users/marius.pingaud/OneDrive - BERGER-LEVRAULT/Bureau/Sorbonne/M2/ML/machine_learning_tryout/Lab1/Datasets/cheese.csv")

# %% [markdown]
# #### Step 2. View the first and last rows

# %%
print(datas)
# Out:
#    cheese;calories;sodium;calcium;lipides;retinol;folates;proteines;cholesterol;magnesium
# 0   CarredelEst;314;353.5;72.6;26.3;51.6;30.3;21;7...
# 1      Babybel;314;238;209.8;25.1;63.7;6.4;22.6;70;27
# 2    Beaufort;401;112;259.4;33.3;54.9;1.2;26.6;120;41
# 3        Bleu;342;336;211.1;28.9;37.1;27.5;20.2;90;27
# 4    Camembert;264;314;215.9;19.5;103;36.4;23.4;60;20
# 5           Cantal;367;256;264;28.8;48.8;5.7;23;90;30
# 6    Chabichou;344;192;87.2;27.9;90.1;36.3;19.5;80;36
# 7   Chaource;292;276;132.9;25.4;116.4;32.5;17.8;70;25
# 8       Cheddar;406;172;182.3;32.5;76.4;4.9;26;110;28
# 9        Comte;399;92;220.5;32.4;55.9;1.3;29.2;120;51
# 10  Coulomniers;308;222;79.2;25.6;63.6;21.1;20.5;8...
# 11        Edam;327;148;272.2;24.7;65.7;5.5;24.7;80;44
# 12    Emmental;378;60;308.2;29.4;56.3;2.4;29.4;110;45
# 13  Fr.chevrepatemolle;206;160;72.8;18.5;150.5;31;...
# 14  Fr.fondu.45;292;390;168.5;24.0;77.4;5.5;16.8;7...
# 15     Fr.frais20nat.;80;41;146.3;3.5;50;20;8.3;10;11
# ...

# %% [markdown]
# #### Step 3.
# By looking at these rows, you probably noticed that the import didn’t go correctly. So, you will now import the dataset properly.
# You will use ';' as the delimiter and specify that the first row contains the column names.

# %%
datas = read_csv("C:/Users/marius.pingaud/OneDrive - BERGER-LEVRAULT/Bureau/Sorbonne/M2/ML/machine_learning_tryout/Lab1/Datasets/cheese.csv", delimiter=';', header=0)

# %% [markdown]
# You can then check once more.
#
# #### Step 4. Check the data types of each column
#
# The second thing to do is a quick check of the data types assigned by Pandas to each column during import, again to ensure that the import was successful.  Display the data type of all columns.

# %%
print(datas)
datas.info()
print(datas.shape)
datas.columns
# Out:
#                 cheese  calories  sodium  calcium  lipides  retinol  folates  \
# 0          CarredelEst       314   353.5     72.6     26.3     51.6     30.3
# 1              Babybel       314   238.0    209.8     25.1     63.7      6.4
# 2             Beaufort       401   112.0    259.4     33.3     54.9      1.2
# 3                 Bleu       342   336.0    211.1     28.9     37.1     27.5
# 4            Camembert       264   314.0    215.9     19.5    103.0     36.4
# 5               Cantal       367   256.0    264.0     28.8     48.8      5.7
# 6            Chabichou       344   192.0     87.2     27.9     90.1     36.3
# 7             Chaource       292   276.0    132.9     25.4    116.4     32.5
# 8              Cheddar       406   172.0    182.3     32.5     76.4      4.9
# 9                Comte       399    92.0    220.5     32.4     55.9      1.3
# 10         Coulomniers       308   222.0     79.2     25.6     63.6     21.1
# ...

# %% [markdown]
# #### Step 5. How many observations are in the dataset?
#
# How many rows and columns are contained in our file?

# %% [markdown]
# There is 29 rows and 10 columns

# %% [markdown]
# #### Step 6. What information is available about the first cheese in the dataset?
#
# It's now time to use the most useful selection function: the [`iloc`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.iloc.html) method.

# %%
print(datas.iloc[0])
# Out:
# cheese         CarredelEst
# calories               314
# sodium               353.5
# calcium               72.6
# lipides               26.3
# retinol               51.6
# folates               30.3
# proteines             21.0
# cholesterol             70
# magnesium               20
# Name: 0, dtype: object

# %% [markdown]
# #### Step 7. Rename the variable `Cheeses` to `Cheeses_name`.

# %%
datas.rename(columns={'cheese':'Cheeses_name'}, inplace=True)
print(datas)
# Out:
#           Cheeses_name  calories  sodium  calcium  lipides  retinol  folates  \
# 0          CarredelEst       314   353.5     72.6     26.3     51.6     30.3
# 1              Babybel       314   238.0    209.8     25.1     63.7      6.4
# 2             Beaufort       401   112.0    259.4     33.3     54.9      1.2
# 3                 Bleu       342   336.0    211.1     28.9     37.1     27.5
# 4            Camembert       264   314.0    215.9     19.5    103.0     36.4
# 5               Cantal       367   256.0    264.0     28.8     48.8      5.7
# 6            Chabichou       344   192.0     87.2     27.9     90.1     36.3
# 7             Chaource       292   276.0    132.9     25.4    116.4     32.5
# 8              Cheddar       406   172.0    182.3     32.5     76.4      4.9
# 9                Comte       399    92.0    220.5     32.4     55.9      1.3
# 10         Coulomniers       308   222.0     79.2     25.6     63.6     21.1
# ...

# %% [markdown]
# #### Step 8. What cheeses are present in the dataset?

# %%
print(datas['Cheeses_name'])
# Out:
# 0            CarredelEst
# 1                Babybel
# 2               Beaufort
# 3                   Bleu
# 4              Camembert
# 5                 Cantal
# 6              Chabichou
# 7               Chaource
# 8                Cheddar
# 9                  Comte
# 10           Coulomniers
# 11                  Edam
# 12              Emmental
# 13    Fr.chevrepatemolle
# 14           Fr.fondu.45
# 15        Fr.frais20nat.
# 16        Fr.frais40nat.
# 17             Maroilles
# 18               Morbier
# 19              Parmesan
# 20         Petitsuisse40
# 21           PontlEveque
# 22              Pyrenees
# 23             Reblochon
# 24            Rocquefort
# 25           SaintPaulin
# 26                  Tome
# 27              Vacherin
# 28    Yaourtlaitent.nat.
# Name: Cheeses_name, dtype: object

# %% [markdown]
# ##### Step 9. Quick analysis of the information in our dataset
#
# Use the [`describe`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.describe.html) and [`info`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.info.html) functions to get some quick information about the variables in our dataframe:

# %%
datas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Cheeses_name  29 non-null     object
#  1   calories      29 non-null     int64
#  2   sodium        29 non-null     float64
#  3   calcium       29 non-null     float64
#  4   lipides       29 non-null     float64
#  5   retinol       29 non-null     float64
#  6   folates       29 non-null     float64
#  7   proteines     29 non-null     float64
#  8   cholesterol   29 non-null     int64
#  9   magnesium     29 non-null     int64
# dtypes: float64(6), int64(3), object(1)
# memory usage: 2.4+ KB

# %% [markdown]
# Based on these descriptions, can you determine the number of non-null elements in the dataset?

# %% [markdown]
# 29 non-null by columns, 10 columns, 290 non-null elements

# %% [markdown]
# ##### Step 10. Selection within a dataframe
#
# ###### a) We have seen how to select a column. Using similar syntax, select two columns of your choice.

# %%
datas[['Cheeses_name', 'magnesium']]
# Out:
#           Cheeses_name  magnesium
# 0          CarredelEst         20
# 1              Babybel         27
# 2             Beaufort         41
# 3                 Bleu         27
# 4            Camembert         20
# 5               Cantal         30
# 6            Chabichou         36
# 7             Chaource         25
# 8              Cheddar         28
# 9                Comte         51
# 10         Coulomniers         13
# 11                Edam         44
# 12            Emmental         45
# 13  Fr.chevrepatemolle         16
# 14         Fr.fondu.45         20
# 15      Fr.frais20nat.         11
# 16      Fr.frais40nat.         10
# 17           Maroilles         40
# 18             Morbier         30
# 19            Parmesan         46
# 20       Petitsuisse40         10
# 21         PontlEveque         22
# 22            Pyrenees         25
# 23           Reblochon         30
# 24          Rocquefort         25
# 25         SaintPaulin         26
# ...

# %% [markdown]
# ###### b) Using the [`loc`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html) method, select and determine the cheeses with low calories (less than 100):

# %%
datas.loc[datas['calories']<100]
# Out:
#           Cheeses_name  calories  sodium  calcium  lipides  retinol  folates  \
# 15      Fr.frais20nat.        80    41.0    146.3      3.5     50.0     20.0
# 28  Yaourtlaitent.nat.        70    91.0    215.7      3.4     42.9      2.9
#
#     proteines  cholesterol  magnesium
# 15        8.3           10         11
# 28        4.1           13         14

# %% [markdown]
# ###### c) Select only the names of these cheeses

# %%
filtered = datas.loc[datas['calories']<100]
filtered[['Cheeses_name']]
# Out:
#           Cheeses_name
# 15      Fr.frais20nat.
# 28  Yaourtlaitent.nat.

# %% [markdown]
# ###### d) Now select the information describing the cheeses with less than 100 calories and more than 5 grams of protein.

# %%
datas.loc[(datas['calories']<100) & (datas['proteines']>5)]
# Out:
#       Cheeses_name  calories  sodium  calcium  lipides  retinol  folates  \
# 15  Fr.frais20nat.        80    41.0    146.3      3.5     50.0     20.0
#
#     proteines  cholesterol  magnesium
# 15        8.3           10         11

# %% [markdown]
# ###### e) For these cheeses, select only their name and the number of proteins.

# %%
filtered = datas.loc[(datas['calories']<100) & (datas['proteines']>5)]
filtered[['Cheeses_name', 'proteines']]
# Out:
#       Cheeses_name  proteines
# 15  Fr.frais20nat.        8.3

# %% [markdown]
# ###### f) Finally, create a new dataframe that will contain only the cheeses with calories greater than or equal to 100.

# %%
datas.loc[datas['calories']>=100]
# Out:
#           Cheeses_name  calories  sodium  calcium  lipides  retinol  folates  \
# 0          CarredelEst       314   353.5     72.6     26.3     51.6     30.3
# 1              Babybel       314   238.0    209.8     25.1     63.7      6.4
# 2             Beaufort       401   112.0    259.4     33.3     54.9      1.2
# 3                 Bleu       342   336.0    211.1     28.9     37.1     27.5
# 4            Camembert       264   314.0    215.9     19.5    103.0     36.4
# 5               Cantal       367   256.0    264.0     28.8     48.8      5.7
# 6            Chabichou       344   192.0     87.2     27.9     90.1     36.3
# 7             Chaource       292   276.0    132.9     25.4    116.4     32.5
# 8              Cheddar       406   172.0    182.3     32.5     76.4      4.9
# 9                Comte       399    92.0    220.5     32.4     55.9      1.3
# 10         Coulomniers       308   222.0     79.2     25.6     63.6     21.1
# ...

# %% [markdown]
# ##### Step 11. Creating new variables
#
# We will create a new dietary column that indicates whether the cheese is suitable for a diet based on the criteria "calories < 100" and "proteins > 5"
#
# fromage['dietetique'] = ((fromage['calories'] < 100) & (fromage['proteines'] > 5)).map({True: 'Yes', False: 'No'})

# %%
datas['dietetique'] = ((datas['calories'] < 100) & (datas['proteines'] > 5)).map({True: 'Yes', False: 'No'})
datas
# Out:
#           Cheeses_name  calories  sodium  calcium  lipides  retinol  folates  \
# 0          CarredelEst       314   353.5     72.6     26.3     51.6     30.3
# 1              Babybel       314   238.0    209.8     25.1     63.7      6.4
# 2             Beaufort       401   112.0    259.4     33.3     54.9      1.2
# 3                 Bleu       342   336.0    211.1     28.9     37.1     27.5
# 4            Camembert       264   314.0    215.9     19.5    103.0     36.4
# 5               Cantal       367   256.0    264.0     28.8     48.8      5.7
# 6            Chabichou       344   192.0     87.2     27.9     90.1     36.3
# 7             Chaource       292   276.0    132.9     25.4    116.4     32.5
# 8              Cheddar       406   172.0    182.3     32.5     76.4      4.9
# 9                Comte       399    92.0    220.5     32.4     55.9      1.3
# 10         Coulomniers       308   222.0     79.2     25.6     63.6     21.1
# ...

# %% [markdown]
# <h2 style="color: blue;">Part 2: Identification and Handling of Missing Values</h2>

# %% [markdown]
# Now, we will address the handling of a DataFrame with issues. You will import the CSV file named 'fromage_V2'.

# %%
df2 = read_csv("C:/Users/marius.pingaud/OneDrive - BERGER-LEVRAULT/Bureau/Sorbonne/M2/ML/machine_learning_tryout/Lab1/Datasets/cheese_V2.csv", delimiter=';', header=0)
df2
# Out:
#                 cheese  calories  sodium  calcium  lipides  retinol  folates  \
# 0          CarredelEst     314.0   353.5     72.6     26.3     51.6     30.3
# 1              Babybel     314.0   238.0    209.8     25.1     63.7      6.4
# 2             Beaufort     401.0   112.0    259.4     33.3     54.9      1.2
# 3                 Bleu     342.0   336.0    211.1     28.9     37.1     27.5
# 4            Camembert     264.0   314.0    215.9     19.5    103.0     36.4
# 5               Cantal     367.0   256.0    264.0     28.8     48.8      5.7
# 6            Chabichou     344.0   192.0     87.2     27.9     90.1     36.3
# 7             Chaource     292.0   276.0    132.9     25.4    116.4     32.5
# 8              Cheddar     406.0   172.0    182.3     32.5     76.4      4.9
# 9                Comte     399.0    92.0    220.5     32.4     55.9      1.3
# 10         Coulomniers     308.0   222.0     79.2     25.6     63.6     21.1
# ...

# %% [markdown]
# ##### Step 12: Identification and Handling of Missing Values
#
# While exploring your DataFrame, you likely noticed an empty column named **'unnamed'** and rows containing null values. You can use methods to check for missing values such as:
# - isna() or isnull()
# - Visualize the distribution of missing values.

# %%
df2.isna()
df2.isnull()

#Count the missing values for each column
df2.isna().sum()

#import missingno as msno
# Visualize the missing values in the DataFrame
#msno.matrix(df2)
# Out:
# cheese          0
# calories        1
# sodium          1
# calcium         1
# lipides         1
# retinol         1
# folates         1
# proteines       1
# cholesterol     1
# magnesium       1
# unnamed        29
# dtype: int64

# %% [markdown]
# To handle missing values, several options are available to you:
#
# ##### 1. **Deletion of rows or columns**
#    You can choose to delete rows or columns containing missing values. This can be useful if the missing data is minimal and its removal does not significantly affect the analysis.
#
# ##### 2. **Filling missing values (imputation)**
#    Imputation involves replacing missing values (or NaNs) with estimated or calculated values. Several techniques are available for imputation:
#    - **Imputation with a constant value**: Replace missing values with a fixed value of your choice.
#    - **Imputation with the mean**: Replace missing values with the mean of the column.
#    - **Imputation with the median**: Use the median to replace missing values, which can be more robust against outliers.
#    - **Imputation with the most frequent value (mode)**: Replace missing values with the most frequent value in the column.
#    - **Imputation with regression**: Use a **regression** model to predict missing values based on other variables in the dataset. This can be more effective when missing values are related to other features of the data.
#
# ##### 3. **Interpolation**
#    You can use **interpolation** methods to estimate missing values based on neighboring values in the column. This is particularly useful in time series data or when the data is ordered.
#
# ---
#
# ##### Choosing the imputation method based on the type of data
#
# The choice of method largely depends on the **context** of your data and the **objective** of your analysis. Here are some guidelines based on the type of data:
#
# - **Numerical data**: For continuous variables such as age, income, or temperature, methods like **mean**, **median**, or even **regression** imputation may be appropriate.
#
# - **Categorical data**: For non-numeric variables, such as categories (e.g., gender or colors), imputation with the **most frequent value** or **regression** (based on explanatory variables) may be more effective.
#
# ---
#
# In summary, it is essential to choose the imputation method that suits the nature of your data and the goal of your analysis. Simple methods like mean or median imputation may suffice for simple cases, while more complex methods like regression or interpolation may be necessary for more advanced scenarios.
#
# ###### a) Deletion of rows or columns

# %%
df2.dropna(axis=1, inplace=True) 
df2
# Out:
#                 cheese
# 0          CarredelEst
# 1              Babybel
# 2             Beaufort
# 3                 Bleu
# 4            Camembert
# 5               Cantal
# 6            Chabichou
# 7             Chaource
# 8              Cheddar
# 9                Comte
# 10         Coulomniers
# 11                Edam
# 12            Emmental
# 13  Fr.chevrepatemolle
# 14         Fr.fondu.45
# 15      Fr.frais20nat.
# 16      Fr.frais40nat.
# 17           Maroilles
# 18             Morbier
# 19            Parmesan
# 20       Petitsuisse40
# 21         PontlEveque
# 22            Pyrenees
# 23           Reblochon
# 24          Rocquefort
# 25         SaintPaulin
# 26                Tome
# 27            Vacherin
# 28  Yaourtlaitent.nat.

# %%
# Mean imputation for missing calorie values
mean_column = df2['calories'].mean()  
df2.fillna({'calories' : mean_column}, inplace=True)
df2
# Out:
#                 cheese  calories  sodium  calcium  lipides  retinol  folates  \
# 0          CarredelEst    314.00   353.5     72.6     26.3     51.6     30.3
# 1              Babybel    314.00   238.0    209.8     25.1     63.7      6.4
# 2             Beaufort    401.00   112.0    259.4     33.3     54.9      1.2
# 3                 Bleu    342.00   336.0    211.1     28.9     37.1     27.5
# 4            Camembert    264.00   314.0    215.9     19.5    103.0     36.4
# 5               Cantal    367.00   256.0    264.0     28.8     48.8      5.7
# 6            Chabichou    344.00   192.0     87.2     27.9     90.1     36.3
# 7             Chaource    292.00   276.0    132.9     25.4    116.4     32.5
# 8              Cheddar    406.00   172.0    182.3     32.5     76.4      4.9
# 9                Comte    399.00    92.0    220.5     32.4     55.9      1.3
# 10         Coulomniers    308.00   222.0     79.2     25.6     63.6     21.1
# ...

# %% [markdown]
# ###### b) Filling missing values with the mean

# %%
df2.fillna(df2.mean(numeric_only=True), inplace=True)
df2
# Out:
#                 cheese  calories      sodium     calcium  lipides     retinol  \
# 0          CarredelEst    314.00  353.500000   72.600000     26.3   51.600000
# 1              Babybel    314.00  238.000000  209.800000     25.1   63.700000
# 2             Beaufort    401.00  112.000000  259.400000     33.3   54.900000
# 3                 Bleu    342.00  336.000000  211.100000     28.9   37.100000
# 4            Camembert    264.00  314.000000  215.900000     19.5  103.000000
# 5               Cantal    367.00  256.000000  264.000000     28.8   48.800000
# 6            Chabichou    344.00  192.000000   87.200000     27.9   90.100000
# 7             Chaource    292.00  276.000000  132.900000     25.4  116.400000
# 8              Cheddar    406.00  172.000000  182.300000     32.5   76.400000
# 9                Comte    399.00   92.000000  220.500000     32.4   55.900000
# 10         Coulomniers    308.00  222.000000   79.200000     25.6   63.600000
# ...

# %% [markdown]
# - Imputation with standard deviation for sodium
# - Imputation with 1 for fats
# - Imputation with the most frequent value for fotales

# %%
deviation = df2['sodium'].std()
df2.fillna({'sodium':deviation}, inplace=True)

df2['fats'] = 1
df2

most_frequent = df2['folates'].mode()[0]
df2.fillna({'folates':most_frequent}, inplace=True)
df2
# Out:
#                 cheese  calories      sodium  calcium  lipides  retinol  \
# 0          CarredelEst    314.00  353.500000     72.6     26.3     51.6
# 1              Babybel    314.00  238.000000    209.8     25.1     63.7
# 2             Beaufort    401.00  112.000000    259.4     33.3     54.9
# 3                 Bleu    342.00  336.000000    211.1     28.9     37.1
# 4            Camembert    264.00  314.000000    215.9     19.5    103.0
# 5               Cantal    367.00  256.000000    264.0     28.8     48.8
# 6            Chabichou    344.00  192.000000     87.2     27.9     90.1
# 7             Chaource    292.00  276.000000    132.9     25.4    116.4
# 8              Cheddar    406.00  172.000000    182.3     32.5     76.4
# 9                Comte    399.00   92.000000    220.5     32.4     55.9
# 10         Coulomniers    308.00  222.000000     79.2     25.6     63.6
# 11                Edam    327.00  148.000000    272.2     24.7     65.7
# ...

# %% [markdown]
# <h2 style="color: blue;"> Matrice de Corrélation </h2>

# %% [markdown]
# A correlation matrix is a table that shows the correlation (linear relationship) between multiple variables in a dataset. Each value in the matrix represents the **strength** and **direction** of the relationship between two variables.
#
# Correlations are often measured using the **Pearson correlation coefficient**, which ranges from **-1 to 1**:
#
# - **1**: Perfect positive correlation (when one variable increases, the other increases proportionally).
# - **-1**: Perfect negative correlation (when one variable increases, the other decreases proportionally).
# - **0**: No correlation (the variables are independent).

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Compute the correlation matrix
corr_matrix = df2.corr(numeric_only=True)

# Visualize with a heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# <h2 style="color: blue;"> Part 4. let's play </h2>
#
# - Import the IRIS dataset from the following URL: [`IRIS`] (https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv)
# - Display the first and last few rows of the DataFrame.
# - Determine the number of rows and columns in the dataset.
# - Display the value in the third row of the "sepal_width" column.
# - Display the entire third row of the DataFrame.
# - Calculate and display the mean of the "sepal_length" column.
# - Calculate and display the standard deviation of the "sepal_length" column.
# - Find and display the minimum value in the "sepal_length" column.
# - Check for missing values in the dataset.
# - Set the values of rows 10 to 29 in the "petal_length" column to NaN.
# - Replace the NaN values in the "petal_length" column with 1.0.
# - Set the first three rows of the DataFrame to NaN.
# - Remove all rows containing NaN values from the DataFrame : [`dropna`](https://pandas.pydata.org/docs/dev/reference/api/pandas.DataFrame.dropna.html)
# - Rename the "species" column to "class".

# %%
df3 = read_csv("C:/Users/marius.pingaud/OneDrive - BERGER-LEVRAULT/Bureau/Sorbonne/M2/ML/machine_learning_tryout/Lab1/Datasets/iris.csv", delimiter=',', header=0)
df3.head(5)
df3.tail(5)
df3.shape
df3['sepal_width'][2]
df3.iloc[2]
df3['sepal_length'].mean()
df3['sepal_length'].std()
df3['sepal_length'].min()
df3.isna().sum()
import numpy as np
df3.loc[10:28, 'petal_length'] = np.nan
df3[10:29]
df3.fillna({'petal_length':1.0}, inplace=True)
df3[10:29]
df3.loc[0:3] = np.nan
df3[0:3]
df3.dropna(inplace=True)
df3
df3.rename(columns={'species':'class'}, inplace=True)
df3.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width   class
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa

# %% [markdown]
# #### Exercice 2.
# Objective: Create a Pandas DataFrame from the two variables declared below. The keys of the dictionary exam_data correspond to the column names of the DataFrame. The list of strings labels corresponds to the index of the DataFrame.
#
# Explore then this dataframe and decide on an appropriate strategy to handle missing data

# %%
import numpy as np
exam_data  = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
        'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
        'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'qualify': ['z', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
df=DataFrame (exam_data, labels)
# I choose to do the mean score of all score below 10 in the dataset, and to implement them in the NaN values
filtered = df[df['score']<10]
score = filtered['score'].mean()
print(score)
df.fillna({'score':score}, inplace=True)
df
# Out:
# 8.666666666666666
#         name      score  attempts qualify
# a  Anastasia  12.500000         1       z
# b       Dima   9.000000         3      no
# c  Katherine  16.500000         2     yes
# d      James   8.666667         3      no
# e      Emily   9.000000         2      no
# f    Michael  20.000000         3     yes
# g    Matthew  14.500000         1     yes
# h      Laura   8.666667         1      no
# i      Kevin   8.000000         2      no
# j      Jonas  19.000000         1     yes

# %% [markdown]
# #### Exercice 3.
# Objective: Work with the Open Food Facts dataset to load and explore the data.
# - Step 1: Navigate to Open Food Facts Dataset on Kaggle : https://www.kaggle.com/datasets/openfoodfacts/world-food-facts
#
# - Step 2: Download the dataset to your computer and unzip it.
#
# - Step 3: Use the TSV (Tab-Separated Values) file and assign it to a DataFrame named food using the following code:

# %%
food = read_csv("C:/Users/marius.pingaud/OneDrive - BERGER-LEVRAULT/Bureau/Sorbonne/M2/ML/machine_learning_tryout/Lab1/Datasets/en.openfoodfacts.org.products.tsv", delimiter='\t', header=0, low_memory=False)
food.shape
food.shape[0]
food.columns
food.columns[104]
# Out:
# '-glucose_100g'

# %%
food
# Out:
#                  code                                                url  \
# 0       0000000003087  http://world-en.openfoodfacts.org/product/0000...
# 1       0000000004530  http://world-en.openfoodfacts.org/product/0000...
# 2       0000000004559  http://world-en.openfoodfacts.org/product/0000...
# 3       0000000016087  http://world-en.openfoodfacts.org/product/0000...
# 4       0000000016094  http://world-en.openfoodfacts.org/product/0000...
# ...               ...                                                ...
# 356022       99567453  http://world-en.openfoodfacts.org/product/9956...
# 356023  9970229501521  http://world-en.openfoodfacts.org/product/9970...
# 356024  9977471758307  http://world-en.openfoodfacts.org/product/9977...
# 356025  9980282863788  http://world-en.openfoodfacts.org/product/9980...
# 356026   999990026839  http://world-en.openfoodfacts.org/product/9999...
#
#                            creator   created_t      created_datetime  \
# ...

# %% [markdown]
# Part 5: Your Turn Again
#
# - Explore the VenteAgence dataset.
#
# - Repeat all the data exploration steps.

# %%
vente = read_csv("C:/Users/marius.pingaud/OneDrive - BERGER-LEVRAULT/Bureau/Sorbonne/M2/ML/machine_learning_tryout/Lab1/Datasets/VentesAgence.csv", delimiter=';', header=0)
vente.shape
vente.columns
# Out:
# Index(['CODE FACTURE', 'DATE FACTURE', 'CODE CLIENT', 'SECTEUR', 'VENDEUR',
#        ' MONTANT ', 'Unnamed: 6'],
#       dtype='object')

# %% [markdown]
# #### Discovering Dates and Extracting More Information from Dates.
#
# Once a column is converted to a date using to_datetime, you can extract various pieces of information from its values.
#
# The column "DATE FACTURE" contains dates. Therefore, it needs to be converted using to_datetime.

# %%
vente['DATE FACTURE'] = to_datetime(vente['DATE FACTURE'], format='mixed')
vente
# Out:
#     CODE FACTURE DATE FACTURE CODE CLIENT      SECTEUR  VENDEUR      MONTANT   \
# 0   FA-2008-0010   2008-12-03      CLI009  AUTOMATISME   BOUVET     752,98
# 1   FA-2008-0006   2008-04-02      CLI038  AUTOMATISME  ENGUENT     374,84
# 2   FA-2008-0009   2008-03-03      CLI098  ELECTRICITE   BOUVET     935,47
# 3   FA-2008-0012   2008-03-31      CLI114  ELECTRICITE  DEVEAUX     752,98
# 4   FA-2008-0008   2008-02-22      CLI115  AUTOMATISME   BOUVET     677,36
# 5   FA-2008-0027   2008-09-07      CLI145  ELECTRICITE   BOUVET     425,81
# 6   FA-2008-0028   2008-09-07      CLI145  AUTOMATISME  ENGUENT   1_607,89
# 7   FA-2008-0029   2008-09-07      CLI163  AUTOMATISME   BOUVET   1_436,91
# 8   FA-2008-0017   2008-05-16      CLI204  AUTOMATISME  ENGUENT   2_250,72
# 9   FA-2008-0031   2008-07-27      CLI204  ELECTRICITE   BOUVET     428,41
# 10  FA-2008-0040   2008-11-09      CLI204  ELECTRICITE  ENGUENT     246,46
# ...

# %% [markdown]
# From this point, we will be able to extract many useful pieces of information:
# - Day
# - Month
# - Year
# - Day of the week
# - Day of the week in text
# - Month in text

# %%
vente['JOUR FACTURE'] = vente['DATE FACTURE'].dt.day
vente['MOIS FACTURE'] = vente['DATE FACTURE'].dt.month
vente['ANNEE FACTURE'] = vente['DATE FACTURE'].dt.year
vente['JOUR SEMAINE'] = vente['DATE FACTURE'].dt.weekday
vente['NOM JOUR'] = vente['DATE FACTURE'].dt.day_name()
vente['NOM MOIS'] = vente['DATE FACTURE'].dt.month_name()

vente['SEMAINE ANNEE'] = vente['DATE FACTURE'].dt.isocalendar().week

vente.sample(5)
# Out:
#     CODE FACTURE DATE FACTURE CODE CLIENT      SECTEUR  VENDEUR      MONTANT   \
# 9   FA-2008-0031   2008-07-27      CLI204  ELECTRICITE   BOUVET     428,41
# 12  FA-2008-0020   2008-06-21      CLI206  AUTOMATISME  DEVEAUX   3_659,69
# 37  FA-2008-0019   2008-12-06      CLI300  ELECTRICITE   BOUVET   1_039,05
# 25  FA-2008-0038   2008-05-09      CLI209  AUTOMATISME   BOUVET     681,78
# 2   FA-2008-0009   2008-03-03      CLI098  ELECTRICITE   BOUVET     935,47
#
#     Unnamed: 6  JOUR FACTURE  MOIS FACTURE  ANNEE FACTURE  JOUR SEMAINE  \
# 9          NaN          27.0           7.0         2008.0           6.0
# 12         NaN          21.0           6.0         2008.0           5.0
# 37         NaN           6.0          12.0         2008.0           5.0
# 25         NaN           9.0           5.0         2008.0           4.0
# 2          NaN           3.0           3.0         2008.0           0.0
#
#     NOM JOUR  NOM MOIS  SEMAINE ANNEE
# 9     Sunday      July             30
# ...

# %% [markdown]
# If we try to retrieve the time from the data in the "DATE_FACTURE" column, we won't be able to, because this information is missing from the original data.

# %%
vente['DATE FACTURE'].dt.time
# Out:
# 0     00:00:00
# 1     00:00:00
# 2     00:00:00
# 3     00:00:00
# 4     00:00:00
# 5     00:00:00
# 6     00:00:00
# 7     00:00:00
# 8     00:00:00
# 9     00:00:00
# 10    00:00:00
# 11    00:00:00
# 12    00:00:00
# 13    00:00:00
# 14    00:00:00
# 15    00:00:00
# 16    00:00:00
# 17    00:00:00
# 18    00:00:00
# 19    00:00:00
# 20    00:00:00
# 21    00:00:00
# 22    00:00:00
# 23    00:00:00
# 24    00:00:00
# 25    00:00:00
# 26    00:00:00
# 27    00:00:00
# 28    00:00:00
# 29    00:00:00
# 30    00:00:00
# 31    00:00:00
# 32    00:00:00
# 33    00:00:00
# 34    00:00:00
# 35    00:00:00
# 36    00:00:00
# 37    00:00:00
# 38    00:00:00
# 39    00:00:00
# 40    00:00:00
# 41    00:00:00
# 42    00:00:00
# 43    00:00:00
# 44    00:00:00
# 45    00:00:00
# 46    00:00:00
# 47         NaT
# 48         NaT
# 49         NaT
# Name: DATE FACTURE, dtype: object
